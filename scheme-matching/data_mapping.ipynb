# %%
import pandas as pd
import recordlinkage
import os

# %%
path = "/Users/vuong/data-integration/res"
mapping_path = "/Users/vuong/data-integration/res/matching"

# %% [markdown]
# ### Cellphones vs hhm

# %%
db_table_path = "/Users/vuong/data-integration/Database/table"
df_phones = pd.read_csv(os.path.join(db_table_path, "phones.csv"), sep =";")
df_sources = pd.read_csv(os.path.join(db_table_path, "sources.csv"), sep =";")
df_sources.astype(str)
df_phones.astype(str)
df_phones['id'] = df_phones['id'].astype('int64')
df_sources['phone_id'] = df_sources['phone_id'].astype('int64')

warehouse = {}
warehouse['phones'] = df_phones
warehouse['sources'] = df_sources

int_field = ["ram", "rom", "battery", "monitor_frequency", "phone_id", "int", 'price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 db_table_path = "/Users/vuong/data-integration/Database/table"
# ----> 2 df_phones = pd.read_csv(os.path.join(db_table_path, "phones.csv"), sep =";")
#       3 df_sources = pd.read_csv(os.path.join(db_table_path, "sources.csv"), sep =";")
#       4 df_sources.astype(str)
#
# NameError: name 'os' is not defined

# %%
def getSource(souce_name, sep=";"):
    df = pd.read_csv(os.path.join(path, souce_name+".csv"), sep = sep)
    df['id'] = df.index
    df.astype(str)
    return df
def getMapping(source_name, sep=";"):
    df = pd.read_csv(os.path.join(mapping_path, source_name+".txt"), sep = sep)
    mapping = {}
    for i in range(df.shape[0]):
        mapping[df['schema'][i]] = df[source_name][i]
    return mapping

# %%
cellphones = getSource("cellphones")
mapping_cellphones = getMapping("cellphones")

hhm = getSource("hhm")
hhm['source'] = 'Hoàng Hà mobile'
mapping_hhm = getMapping("hhm")

nk = getSource("nk")
nk['source'] = 'Nguyễn Kim mobile'
mapping_nk = getMapping("nk")

tgdd = getSource("tgdd")
tgdd['source'] = 'Thế giới di động'
mapping_tgdd = getMapping('tgdd')

# %%
def load_data(source, target, mapping):
    t = target.copy()
    for key in mapping:
        for table in t:
            t[table] = t[table].copy()
            df_table = t[table]
            if key in df_table.columns:
                target_table = df_table
        target_table[key] = source[mapping[key]]

    t['sources']['phone_id'] = source['id']
    t['phones']['id'] = source['id']
    return t

# %%
def load_match_data(source, target, id_mapping, mapping):
    t = {}
    phones = target['phones'].copy()
    sources = target['sources'].copy()
    df_not_matched = pd.DataFrame()
    df_matched = pd.DataFrame()

    df_not_matched= source[~source['id'].isin(id_mapping.keys())]
    df_matched = source[source['id'].isin(id_mapping.keys())]

    for index, row in df_matched.iterrows():
        data_row_left = {}
        for field in source.columns:
            data_row_left[field] = row[field]
        id_left = data_row_left['id']
        row_right = phones.loc[phones['id'] == id_mapping[id_left]]
        for index, row in row_right.iterrows():
            for field in phones.columns:
                if field in mapping:
                    if str(phones.at[index, field]) == 'nan':
                        phones.at[index, field] = data_row_left[mapping[field]]

        data_source = {}
        for field in sources.columns:
            if field in mapping:
                data_source[field] = (data_row_left[mapping[field]])
            elif field =='phone_id':
                data_source[field] = (id_mapping[id_left])
            else :
                data_source[field] = ("")

        data_source = pd.DataFrame([data_source])
        sources = pd.concat([sources,data_source] , axis=0, ignore_index=True)


    #if object is not exist in warehouse
    for index, row in df_not_matched.iterrows():
        data_row = {}
        for field in source.columns:
            data_row[field] = row[field]
        data_row['id'] = phones.shape[0]
        data_phone = {}
        for field in phones.columns:
            if field in mapping:
                data_phone[field] = (data_row[mapping[field]])
            elif field == 'id':
                data_phone['id'] = (data_row['id'])
            else :
                data_phone[field] = ("")

        data_source = {}
        for field in sources.columns:
            if field in mapping:
                data_source[field] = (data_row[mapping[field]])
            elif field =='phone_id':
                data_source[field] = (data_row['id'])
            else :
                data_source[field] = ("")

        data_phone = pd.DataFrame([data_phone])
        data_source = pd.DataFrame([data_source])
        phones = pd.concat([phones, data_phone] , axis=0, ignore_index=True)
        sources = pd.concat([sources,data_source] , axis=0, ignore_index=True)

    t['phones'] = phones
    t['sources'] = sources
    return t

# %%
def nomalize_data(df, mapping):
    df = df.copy()
    for key in mapping:
        if key in int_field and df[mapping[key]].dtype == 'object':
            for i in range(df.shape[0]):
                a = ''.join(filter(str.isdigit, str(df[mapping[key]][i])))
                df[mapping[key]][i] = a
    return df

# %%
def data_matching(left_df, left_col, right_df, right_col):
    df = fuzzymatcher.fuzzy_left_join(left_df, right_df, left_col, right_col, left_id_col = "id", right_id_col = "id")
    return df

# %%
def get_data_match(df_source, target, mapping, min_accept=0.5):
    if (target['phones'].shape[0] == 0) :
        return pd.DataFrame()
    target_cols = ["name", "ram", "rom"]
    source_cols = [mapping[x] for x in target_cols]
    data_match = data_matching(df_source , source_cols, target['phones'], target_cols)
    data_match = data_match.sort_values(by=['best_match_score'], ascending=False)
    data_match = data_match[data_match['best_match_score'] > min_accept]
    return data_match

# %%
def show_data_match(data_match, mapping):
   target_cols = ["name", "ram", "rom"]
   show_col = ['best_match_score', '__id_left', '__id_right']
   for col in target_cols:
      if (mapping[col] == col):
         show_col.append(col+'_left')
         show_col.append(col+'_right')
      else:
         show_col.append(col)
         show_col.append(mapping[col])

   data = data_match[data_match.columns.intersection(show_col)]
   return data

# %%
def data_maping(df_source, target, mapping, min_accept=0.5):
    df_source = nomalize_data(df_source,mapping)
    data = get_data_match(df_source, target, mapping, min_accept)

    if (data.empty):
        warehouse = load_data(df_source, target,mapping)
        return warehouse

    id_left = data['__id_left'].to_list()
    id_right = data['__id_right'].to_list()
    
    id_mapping = {}
    for i in range(len(id_left)):
        id_mapping[id_left[i]] = id_right[i]

    t = load_match_data(df_source, target, id_mapping, mapping)
    return t

# %% [markdown]
# # MAPPING DATA

# %%
warehouse = data_maping(cellphones, warehouse, mapping_cellphones)

# %%
warehouse = data_maping(hhm, warehouse, mapping_hhm)

# %%
warehouse = data_maping(nk, warehouse, mapping_nk, 0.1)

# %%
warehouse = data_maping(tgdd, warehouse, mapping_tgdd, 0.3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/data-integration/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/data-integration/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/data-integration/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 warehouse = data_maping(tgdd, warehouse, mapping_tgdd, 0.3)
#
# Cell In[26], line 2, in data_maping(df_source, target, mapping, min_accept)
#       1 def data_maping(df_source, target, mapping, min_accept=0.5):
# ----> 2     df_source = nomalize_data(df_source,mapping)
#       3     data = get_data_match(df_source, target, mapping, min_accept)
#       5     if (data.empty):
#
# Cell In[25], line 4, in nomalize_data(df, mapping)
#       2 df = df.copy()
#       3 for key in mapping:
# ----> 4     if key in int_field and df[mapping[key]].dtype == 'object':
#       5         for i in range(df.shape[0]):
#       6             a = ''.join(filter(str.isdigit, str(df[mapping[key]][i])))
#
# File ~/data-integration/.venv/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/data-integration/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'ram'

# %% [markdown]
# # Output

# %%
warehouse['sources']['phone_id'] = warehouse['sources']['phone_id'].astype('int64')

# %%
warehouse['phones'].to_csv(os.path.join(db_table_path, "phones.csv"), sep =";",index=False)
warehouse['sources'].to_csv(os.path.join(db_table_path, "sources.csv"), sep =";", index=False)

# %%
warehouse
# Out:
# {'phones':       id                                               name  \
#  0      0        Apple iPhone 8 64GB Chính hãng
#  1      1        iPhone XR 128GB I Chính hãng VN/A
#  2      2        iPhone XR 64GB I Chính hãng VN/A
#  3      3        ASUS 8z
#  4      4        ASUS ROG Phone 2 512GB
#  ..   ...                                                ...
#  967  967  Xiaomi 12 - Chính hãng                        ...
#  968  968  Xiaomi Redmi Note 10 Pro 8GB/128GB - Chính hãn...
#  969  969  Điện thoại Samsung Galaxy A13 4GB/128GB Đen   ...
#  970  970  Điện thoại Vivo Y21s 4GB/128GB Xanh           ...
#  971  971  Điện thoại Vivo Y21s 6GB/128GB Trắng          ...
#
#                        display_size  \
#  0          4.7 inches
#  1          6.1 inches
#  2          6.1 inches
#  3          5.9 inches
#  4          6.59 inches
#  ..                             ...
#  967  6.28 inches
#  968  6.67"
#  969                       6.6 "
#  970                       6.51 "
#  971                       6.51 "
#
#                                            display_tech  \
#  0                                                  ...
#  1     IPS LCD                                      ...
#  2     IPS LCD                                      ...
#  3     AMOLED                                       ...
#  4                                                  ...
#  ..                                                 ...
#  967  AMOLED  1 tỷ màu  HDR10+  120Hz  tỷ lệ 209  6....
#  968  AMOLED                                        ...
#  969   FHD+ Infinity-V                              ...
#  970   LCD                                          ...
#  971   LCD                                          ...
#
#                                                  camera  \
#  0     12 MP (f/1.8  28mm)  tự động lấy nét nhận diệ...
#  1     12MP                                         ...
#  2     12MP                                         ...
#  3     Camera chính: 64 MP  f/1.73  16 MP           ...
#  4     48 MP + 13 MP                                ...
#  ..                                                 ...
#  967  50 MP  f/1.9  26mm (góc rộng)  PDAF  OIS  13 M...
#  968  Chính 108 MP & Phụ 8 MP  5 MP  2 MP  16 MP    ...
#  969   Sau 50MP + Chụp Góc Siêu Rộng 5MP + Xoá phông...
#  970   50MP + 2MP + 2MP                             ...
#  971   50MP + 2MP + 2MP                             ...
#
#                                           camera_selfie   ram    rom  \
#  0     7 MP  f/2.2  1080p@30fps  720p@240fps  nhận d...         64.0
#  1     7MP                                          ...   3.0  128.0
#  2     7MP                                          ...   3.0   64.0
#  3     12 MP                                        ...   8.0  128.0
#  4     24 MP                                        ...  12.0  512.0
#  ..                                                 ...   ...    ...
#  967                                                        8    256
#  968                                                        8    128
#  969                           8MP                          4    128
#  970                           8MP                          4    128
#  971                           8MP                          6    128
#
#                  battery                                                sim  \
#  0                1821.0   Nano-SIM                                     ...
#  1                2942.0   Nano-SIM                                     ...
#  2                2942.0   Nano-SIM                                     ...
#  3                4000.0   2 SIM (Nano-SIM)                             ...
#  4              600040.0   Nano-SIM                                     ...
#  ..                  ...                                                ...
#  967  450067100395010053          2 SIM  Nano SIM
#  968                5020          2 Nano SIM
#  969
#  970
#  971
#
#                                        operating_system  \
#  0     11                                           ...
#  1     iOS 12                                       ...
#  2     iOS 14                                       ...
#  3     Android 11                                   ...
#  4     Android 9.0 (Pie)                            ...
#  ..                                                 ...
#  967                                                NaN
#  968          Android 11
#  969                                                ...
#  970   Funtouch OS 11.1 (Tuỳ biến trên Android 11)  ...
#  971   Funtouch OS 11.1 (Tuỳ biến trên Android 11)  ...
#
#                                              resolution  \
#  0     750 x 1334 pixels                            ...
#  1     1792 x 828 pixel                             ...
#  2     1792 x 828 pixel                             ...
#  3     1080 x 2400 pixels (FullHD+)                 ...
#  4     1080 x 2340 pixels (FullHD+)                 ...
#  ..                                                 ...
#  967
#  968
#  969
#  970                     HD+ (1600*720)  pixels
#  971                     HD+ (1600*720)  pixels
#
#                                         display_feature  \
#  0                                                  ...
#  1     True-tone                                    ...
#  2     True-tone  tần số quét 60Hz  mật độ điểm ảnh ...
#  3     Độ sáng tối đa 1100 nits  112% DCI-P3  107% N...
#  4                                                  ...
#  ..                                                 ...
#  967
#  968
#  969
#  970
#  971
#
#                                                cpu_type  \
#  0     2x 2.39 GHz Monsoon & 4x 2.39 GHz Mistral    ...
#  1     Hexa-core                                    ...
#  2     Hexa-core                                    ...
#  3                                                  ...
#  4     64-bit Octa-core                             ...
#  ..                                                 ...
#  967
#  968
#  969
#  970
#  971
#
#                                                  weight monitor_frequency  \
#  0     148 g (5.22 oz)                              ...
#  1     194 g                                        ...              60.0
#  2     194 g                                        ...              60.0
#  3     169 g                                        ...             120.0
#  4     240 g                                        ...             120.0
#  ..                                                 ...               ...
#  967
#  968
#  969
#  970
#  971
#
#                                                  cpu  \
#  0     Apple A11 Bionic APL1W72
#  1     Apple A12 Bionic
#  2     Apple A12 Bionic
#  3     Qualcomm® Snapdragon™ 888 5G
#  4     Snapdragon 855 Plus Mobile Platform
#  ..                                              ...
#  967         Qualcomm SM8450 Snapdragon 8 Gen 1 (4 n
#  968         Snapdragon 732G 8 nhân
#  969    Exynos850 (8 nhân)
#  970    Mediatek Helio G80
#  971    Mediatek Helio G80
#
#                                    bluetooth  \
#  0     5.0  A2DP  LE
#  1     v5.0  A2DP  LE
#  2     v5.0  A2DP  LE
#  3     5.2 (EDR + A2DP)  hỗ trợ LDAC  Qualco
#  4     V 5.0 (BR/EDR+LE)  hỗ trợ Qualcomm® a
#  ..                                      ...
#  967
#  968
#  969
#  970                        Bluetooth 5.0\t
#  971                        Bluetooth 5.0\t
#
#                                                   image
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  967  https://cdn.hoanghamobile.com/i/productlist/ts...
#  968  https://cdn.hoanghamobile.com/i/productlist/ts...
#  969  https://www.nguyenkim.com/dien-thoai-samsung-g...
#  970  https://www.nguyenkim.com/dien-thoai-vivo-y21s...
#  971  https://www.nguyenkim.com/dien-thoai-vivo-y21s...
#
#  [972 rows x 19 columns],
#  'sources':       phone_id             source       price  \
#  0            0         cellphoneS  10020000.0
#  1            1         cellphoneS  13000000.0
#  2            2         cellphoneS  12900000.0
#  3            3         cellphoneS         0.0
#  4            4         cellphoneS  20490000.0
#  ...        ...                ...         ...
#  1588       622  Nguyễn Kim mobile     5990000
#  1589       608  Nguyễn Kim mobile     5990000
#  1590       969  Nguyễn Kim mobile     3850000
#  1591       970  Nguyễn Kim mobile     3890000
#  1592       971  Nguyễn Kim mobile     4290000
#
#                                                      url
#  0      https://cellphones.com.vn/apple-iphone-8-64-g...
#  1      https://cellphones.com.vn/apple-iphone-xr-128...
#  2      https://cellphones.com.vn/apple-iphone-xr-64-...
#  3      https://cellphones.com.vn/asus-8z.html       ...
#  4      https://cellphones.com.vn/asus-rog-phone-2.ht...
#  ...                                                 ...
#  1588  https://www.nguyenkim.com/dien-thoai-xiaomi-re...
#  1589  https://www.nguyenkim.com/dien-thoai-xiaomi-re...
#  1590  https://www.nguyenkim.com/dien-thoai-samsung-g...
#  1591  https://www.nguyenkim.com/dien-thoai-vivo-y21s...
#  1592  https://www.nguyenkim.com/dien-thoai-vivo-y21s...
#
#  [1593 rows x 4 columns]}
